# %%
import pickle

with open('50_5_actions.pkl', 'rb') as f:
    data = pickle.load(f)
   
    
print(data)
# Out:
# [1, 8, 8, 8, 8, 3, 3, 8, 3, 2, 8, 8, 7, 5, 7, 8, 8, 7, 8, 8, 3, 3, 8, 3, 1, 5, 1, 8, 8, 8, 3, 5, 8, 8, 8, 5, 8, 8, 8, 5, 8, 4, 8, 2, 8, 8, 8, 8, 7, 8, 8, 8, 0, 8, 8, 1, 8, 8, 1, 8, 8, 8, 8, 8, 8, 5, 1, 8, 8, 8, 8, 1, 5, 8, 4, 8, 8, 1, 1, 3, 8, 8, 5, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 7, 8, 8, 7, 8, 8, 7, 8, 5, 8, 8, 8, 8, 1, 8, 3, 8, 8, 8, 8, 8, 8, 8, 1, 1, 8, 8, 8, 3, 5, 1, 8, 8, 8, 8, 7, 1, 6, 8, 3, 8, 8, 3, 8, 8, 8, 8, 8, 8, 8, 5, 8, 1, 8, 1, 1, 8, 8, 1, 2, 2, 8, 8, 8, 8, 0, 7, 8, 8, 8, 8, 3, 8, 8, 8, 7, 3, 1, 8, 8, 1, 8, 7, 8, 8, 8, 8, 3, 8, 8, 8, 1, 3, 8, 7, 8, 8, 1, 3, 3, 4, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 1, 7, 7, 8, 8, 7, 8, 8, 8, 2, 8, 1, 1, 8, 0, 8, 8, 8, 8, 8, 5, 8, 8, 8, 8, 5, 7, 1, 8, 8, 8, 4, 8, 7, 8, 8, 5, 8, 1, 8, 8, 3, 3, 8, 8, 3, 8, 7, 8, 3, 8, 8, 8, 8, 8, 8, 3, 8, 5, 8, 8, 1, 4, 8, 8, 8, 7, 8, 2, 8, 8, 8, 8, 8, 5, 8, 3, 8, 8, 5, 8, 8, 1, 8, 8, 8, 7, 7, 8, 3, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 2, 8, 8, 8, 8, 7, 1, 8, 5, 8, 8, 1, 7, 8, 8, 8, 8, 8, 8, 8, 8, 0, 1, 8, 5, 8, 8, 6, 8, 3, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 7, 1, 3, 8, 8, 8, 8, 8, 1, 8, 8, 8, 0, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 3, 8, 8, 8, 3, 8, 8, 8, 8, 8, 8, 4, 8, 1, 8, 1, 8, 8, 4, 8, 3, 8, 8, 8, 8, 8, 8, 1, 8, 8, 8, 8, 6, 7, 8, 8, 8, 8, 8, 8, 8, 8, 5, 5, 4, 8, 8, 8, 8, 8, 8, 8, 1, 8, 4, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 2, 8, 1, 8, 8, 8, 8, 8, 7, 8, 8, 1, 8, 8, 8, 1, 2, 8, 8, 8, 3, 7, 8, 3, 8, 1, 8, 8, 8, 8, 1, 8, 8, 8, 8, 5, 8, 8, 3, 8, 8, 5, 8, 7, 1, 8, 8, 8, 8, 8, 8, 7, 8, 8, 8, 8, 8, 8, 8, 8, 1, 8, 8, 8, 7, 8, 3, 5, 8, 8, 3, 2, 8, 8, 8, 8, 3, 3, 8, 8, 8, 3, 8, 3, 8, 8, 8, 8, 8, 3, 8, 1, 8, 5, 2, 8, 5, 1, 5, 8, 8, 8, 5, 8, 1, 1, 7, 8, 7, 7, 8, 1, 8, 8, 7, 8, 8, 8, 8, 8, 1, 8, 8, 8, 7, 5, 8, 8, 8, 1, 5, 1, 1, 8, 8, 8, 8, 8, 1, 8, 8, 8, 8, 3, 1, 8, 8, 5, 8, 8, 1, 8, 5, 8, 8, 8, 8, 1, 8, 8, 6, 8, 0, 8, 8, 3, 8, 8, 8, 8, 8, 8, 7, 8, 5, 8, 8, 8, 8, 8, 3, 8, 8, 8, 8, 8, 1, 8, 7, 8, 8, 8, 8, 1, 7, 8, 8, 8, 8, 8, 4, 8, 8, 6, 8, 2, 8, 8, 8, 1, 8, 8, 7, 8, 8, 8, 8, 1, 8, 4, 8, 8, 7, 1, 8, 8, 4, 8, 3, 4, 3, 8, 1, 8, 1, 8, 3, 8, 8, 8, 8, 8, 8, 1, 8, 8, 8, 8, 8, 7, 8, 8, 5, 8, 8, 8, 4, 3, 8, 1, 1, 2, 8, 5, 3, 8, 8, 5, 8, 8, 8, 7, 1, 1, 8, 8, 7, 8, 7, 8, 8, 8, 8, 1, 8, 3, 4, 8, 8, 3, 8, 5, 8, 8, 8, 4, 8, 8, 5, 5, 7, 8, 8, 8, 1, 8, 1, 8, 8, 6, 5, 8, 8, 8, 1, 8, 8, 4, 8, 2, 8, 8, 8, 8, 1, 8, 8, 5, 2, 8, 4, 8, 8, 8, 8, 1, 8, 8, 4, 5, 8, 8, 8, 0, 8, 8, 3, 5, 8, 8, 8, 8, 8, 8, 8, 8, 8, 4, 8, 7, 8, 8, 5, 8, 8, 3, 8, 8, 6, 8, 8, 8, 8, 8, 8, 7, 8, 8, 8, 8, 8, 8, 2, 8, 7, 1, 1, 8, 8, 8, 8, 8, 8, 8, 3, 5, 8, 8, 7, 8, 8, 8, 8, 8, 5, 8, 8, 8, 8, 3, 4, 1, 8, 8, 5, 8, 3, 8, 1, 8, 5, 4, 5, 1, 8, 8, 8, 8, 8, 8, 5, 0, 2, 8, 1, 1, 8, 8, 8, 1, 0, 7, 8, 1, 8, 8, 1, 8, 3, 8, 1, 7, 8, 8, 8, 8, 1, 8, 8, 8, 8, 8, 8, 7, 1, 3, 7, 2, 1, 1, 6, 8, 8, 8, 5, 8, 3, 8, 8, 8, 1, 8, 8, 8, 1, 8, 8, 8, 8, 8, 7, 8, 8, 8, 8, 8, 3, 1, 5, 1, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 3, 8, 8, 7, 8, 8, 8, 8, 7, 3, 7, 8, 8, 8, 8, 8, 1, 8, 8, 8, 1, 1, 8, 8, 3, 5, 7, 8, 8, 8, 1, 8, 8, 8, 8, 4, 7, 8, 7, 8, 5, 8, 1, 8, 2, 6, 8, 8, 8, 1, 8, 8, 8, 8, 8, 8, 1, 8, 8, 7, 2, 8, 4, 7, 8, 8, 8, 8, 8, 8, 8, 8, 1, 8, 8, 8, 2, 8, 8, 8, 8, 7, 8, 8, 8, 7, 8, 8, 3, 8, 8, 1, 8, 8, 8, 1, 8, 7, 8, 8, 3, 1, 8, 7, 1, 8, 8, 5, 1, 3, 7, 8, 8, 2, 1, 8, 6, 8, 8, 7, 8, 8, 4, 7, 8, 5, 8, 8, 8, 7, 8, 8, 5, 1, 1, 1, 8, 8, 1, 0, 8, 8, 5, 3, 7, 1, 8, 8, 2, 3, 8, 8, 2, 8, 7, 8, 3, 8, 8, 3, 8, 8, 8, 8, 8, 1, 8, 8, 8, 8, 6, 7, 3, 8, 8, 8, 8, 1, 8, 7, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 7, 8, 8, 7, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 7, 7, 8, 8, 8, 7, 5, 8, 3, 8, 8, 8, 8, 3, 8, 8, 1, 8, 8, 5, 7, 1, 8, 8, 8, 8, 8, 8, 8, 3, 3, 1, 8, 8, 8, 8, 5, 8, 8, 7, 6, 4, 8, 8, 8, 5, 3, 8, 8, 8, 3, 1, 8, 3, 8, 8, 8, 8, 8, 8, 8, 3, 7, 1, 8, 8, 8, 8, 5, 8, 5, 8, 8, 8, 8, 5, 6, 1, 8, 1, 8, 7, 8, 8, 8, 8, 8, 4, 8, 8, 8, 7, 5, 7, 1, 1, 1, 8, 8, 0, 8, 3, 7, 1, 0, 1, 5, 7, 8, 8, 8, 8, 8, 8, 8, 7, 8, 1, 8, 8, 7, 8, 8, 8, 8, 8, 4, 3, 8, 0, 5, 8, 8, 8, 8, 7, 8, 3, 8, 5, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 7, 8, 4, 8, 8, 8,  ...

# %%
import matplotlib.pyplot as plt

plt.hist(data, bins=10)

plt.show()

# %%
import matplotlib.pyplot as plt

def process_list(input_list, hop):
    result = []
    
    for i in range(0, len(input_list), hop):
        # Extract the next 'hop' elements
        chunk = input_list[i:i + hop]
        
        # Sum the elements after incrementing by 1
        chunk_sum = sum([x + 1 for x in chunk])
        
        # Divide each element by the chunk sum (if chunk_sum is not zero)
        processed_chunk = sorted([(x + 1) / chunk_sum for x in chunk])

        # Append the processed chunk as a sublist
        result.append(processed_chunk)
    
    return result

# Function to sum the distributions element-wise
def sum_distributions(chunks):
    max_length = max(len(chunk) for chunk in chunks)
    
    # Initialize an array to hold the sum distribution with zeros
    summed_distribution = [0] * max_length
    
    for chunk in chunks:
        for j, val in enumerate(chunk):
            summed_distribution[j] += val
    
    
    summed_distribution = [x / len(chunks) for x in summed_distribution]
    return summed_distribution

# Example usage

output_chunks = process_list(data, 5)

# Sum the distributions
summed_distribution = sum_distributions(output_chunks)

# Plot the summed distribution
plt.plot(summed_distribution)
plt.title("Summed Distribution")
plt.xlabel("Element Index")
plt.ylabel("Summed Value")
plt.ylim(0, 1)
plt.show()

# %%
def process_list_(input_list, hop):
    result = []
    
    for i in range(0, len(input_list), hop):
        # Extract the next 'hop' elements
        chunk = input_list[i:i + hop]
        
        # Sum the elements after incrementing by 1
        chunk_sum = sum([x + 1 for x in chunk])
        
        # Divide each element by the chunk sum (if chunk_sum is not zero)
        chunk_sum = [(x + 1) / chunk_sum for x in chunk]

        # Append the processed chunk as a sublist
        result.extend(chunk_sum)
    
    return result

output_list = process_list_(data, 5)

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
sns.histplot(output_list, kde=True, bins = 50)
plt.show()

# %%
import pickle
from statistics import *

with open('50_5_rewards.pkl', 'rb') as f:
    data = pickle.load(f)
   
    
print(stdev(data))
print(mean(data))
# Out:
# 0.38458175376074505
# 0.6798906757850001
